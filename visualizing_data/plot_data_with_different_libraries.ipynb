# %%
import pandas as pd

# %%
data = pd.read_csv('dm_office_sales.csv')
data
# Out:
#               division  level of education  training level  work experience  \
# 0             printers        some college               2                6
# 1             printers  associate's degree               2               10
# 2          peripherals         high school               0                9
# 3      office supplies  associate's degree               2                5
# 4      office supplies         high school               1                5
# ..                 ...                 ...             ...              ...
# 995  computer hardware  associate's degree               1                1
# 996  computer software  associate's degree               1                0
# 997        peripherals  associate's degree               2                8
# 998        peripherals  associate's degree               2                3
# 999  computer hardware        some college               0                9
#
#      salary   sales
# 0     91684  372302
# ...

# %%
x = data['sales']
y = data['salary']

# %%
import matplotlib.pyplot as plt
plt.scatter(x, y)
plt.xlabel('Sales')
plt.ylabel('Salary')
plt.title('Sales vs Salary')
# Out:
# Text(0.5, 1.0, 'Sales vs Salary')

# %%
data.plot(kind='scatter', x='sales', y='salary') # using pandas' built-in plotting
# Out:
# <Axes: xlabel='sales', ylabel='salary'>

# %%
import seaborn as sns
sns.scatterplot(x = 'salary', y = 'sales', data = data,hue='division')
# Out:
# <Axes: xlabel='salary', ylabel='sales'>

# %%
import seaborn as sns
sns.scatterplot(x = 'salary', y = 'sales', data = data,hue='level of education')
# Out:
# <Axes: xlabel='salary', ylabel='sales'>

# %%
x = [1,2,3,4,5]
f = ['apple', 'banana', 'cherry', 'date', 'elderberry']
g = [10, 20, 30, 40, 50]

d = {'numbers': x, 'fruits': f, 'values': g}
df = pd.DataFrame(data=d)
df
# Out:
#    numbers      fruits  values
# 0        1       apple      10
# 1        2      banana      20
# 2        3      cherry      30
# 3        4        date      40
# 4        5  elderberry      50
